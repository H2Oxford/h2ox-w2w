# %%
import pandas as pd
from sklearn.metrics import r2_score

# %%
import json

# %%
reservoirs = ['harangi','kabini','krishnaraja_sagar','bhadra','lower_bhawani','hemavathy']

# %%
import os

# %%
root = os.path.abspath(os.path.join(os.getcwd(),'..'))

# %%
root

# %%
data = {kk:json.load(open(os.path.join(root,'w2w_results',f'{kk}_r2score.json'),'r')) for kk in reservoirs}

# %%
import matplotlib
matplotlib.style.use('ggplot')

# %%
pd.DataFrame(data).T.plot.bar(figsize=(20,10), cmap='viridis', rot=0).legend(loc='center left',bbox_to_anchor=(1.0, 0.5))
